# %%
import warnings
#スクリプト実行時に表示される警告メッセージを制御
warnings.filterwarnings("ignore") 

import os
#tokenizerライブラリ使用時の並列処理を抑制
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import numpy as np

def read_data(filename):
    labels, sentences = [], []
    with open(filename) as f:
        for line in f:
            t = int(line[0])
            labels.append([1-t, t])
            sentences.append(line[1:].strip())
            
    return np.array(labels), sentences

train_labels, train_sentences = read_data('mc_train_data_jp.txt')
dev_labels, dev_sentences = read_data('mc_dev_data_jp.txt')
test_labels, test_sentences = read_data('mc_test_data_jp.txt')

# %%
import spacy
nlp = spacy.load("ja_core_news_trf")
import ja_core_news_trf
nlp = ja_core_news_trf.load()
doc = nlp("これは文章です。")
print([(w.text, w.pos_) for w in doc])

# %%
train_tokenised
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
from lambeq import cups_reader
import japanize_matplotlib


raw_train_diagrams = []
raw_dev_diagrams = []
raw_test_diagrams = []

for i in range(len(train_tokenised)):
    raw_train_diagrams.append(cups_reader.sentence2diagram(train_tokenised[i], tokenised=True))
for i in range(len(dev_tokenised)):
    raw_dev_diagrams.append(cups_reader.sentence2diagram(dev_tokenised[i], tokenised=True))
for i in range(len(test_tokenised)):
    raw_test_diagrams.append(cups_reader.sentence2diagram(test_tokenised[i], tokenised=True))

train_diagrams = raw_train_diagrams
dev_diagrams = raw_dev_diagrams
test_diagrams = raw_test_diagrams
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 10
#       7 raw_test_diagrams = []
#       9 for i in range(len(train_tokenised)):
# ---> 10     raw_train_diagrams.append(cups_reader.sentence2diagram(train_tokenised[i], tokenised=True))
#      11 for i in range(len(dev_tokenised)):
#      12     raw_dev_diagrams.append(cups_reader.sentence2diagram(dev_tokenised[i], tokenised=True))
#
# File c:\Users\neoia\anaconda3\envs\lambeq_env2\Lib\site-packages\lambeq\text2diagram\linear_reader.py:92, in LinearReader.sentence2diagram(self, sentence, tokenised)
#      90     sentence = sentence.split()
#      91 words = (Word(word, self.word_type) for word in sentence)
# ---> 92 diagram = self.start_box.tensor(*words)
#      93 while len(diagram.cod) > 1:
#      94     diagram >>= (self.combining_diagram @
#      95                  Id(diagram.cod[len(self.combining_diagram.dom):]))
#
# File c:\Users\neoia\anaconda3\envs\lambeq_env2\Lib\site-packages\lambeq\backend\grammar.py:884, in Diagram.tensor(self, *diagrams)
#     881 except ValueError:
#     882     return NotImplemented
# --> 884 right = dom = self.dom.tensor(*[
#     885     diagram.to_diagram().dom for diagram in diagrams
#     886 ])
#     887 left = self.category.Ty()
#     888 layers = []
#
# TypeError: Ty.tensor() missing 1 required positional argument: 'other'

# %%
raw_train_diagrams[0].draw(figsize=(14,3), fontsize=12)
train_diagrams[0].draw
