# %%
from datasets import load_dataset

# データセットを読み込む
dataset = load_dataset("dair-ai/emotion")

# 各分割をCSVとして保存
dataset["train"].to_csv(r"C:\Users\neoia\研究\data\emotion\emotion_train.csv", index=False)
dataset["validation"].to_csv(r"C:\Users\neoia\研究\data\emotion\emotion_validation.csv", index=False)
dataset["test"].to_csv(r"C:\Users\neoia\研究\data\emotion\emotion_test.csv", index=False)
# Out:
# ...
# Creating CSV from Arrow format: 100%|██████████| 2/2 [00:00<00:00, 205.26ba/s]
# 201185

# %%
import pandas as pd

# ファイルパス
train_path = r"C:\Users\neoia\研究\data\emotion\emotion_train.csv"
val_path   = r"C:\Users\neoia\研究\data\emotion\emotion_validation.csv"
test_path  = r"C:\Users\neoia\研究\data\emotion\emotion_test.csv"

# CSVを読み込む
train_df = pd.read_csv(train_path)
val_df   = pd.read_csv(val_path)
test_df  = pd.read_csv(test_path)

# 各ファイルで文章とラベルを分けてリスト化
train_texts = train_df["text"].tolist()
train_labels = train_df["label"].tolist()

val_texts = val_df["text"].tolist()
val_labels = val_df["label"].tolist()

test_texts = test_df["text"].tolist()
test_labels = test_df["label"].tolist()
