# %%
input_file = "C:/Users/neoia/研究/mc_dev_data.txt"
output_file = "C:/Users/neoia/研究/mc_dev_data_new.txt"

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        line = line.strip()
        if not line:
            continue
        label, sentence = line[0], line[1:].strip()  # ラベルと文に分割
        if sentence.endswith(" ."):
            sentence = sentence[:-2] + "."  # ピリオドの前のスペースを削除
        sentence = sentence[0].upper() + sentence[1:]  # 文の頭を大文字に
        outfile.write(f"{label} {sentence}\n")

# %%
input_file = "C:/Users/neoia/研究/mc_train_data.txt"
output_file = "C:/Users/neoia/研究/mc_train_data_new.txt"

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        line = line.strip()
        if not line:
            continue
        label, sentence = line[0], line[1:].strip()  # ラベルと文に分割
        if sentence.endswith(" ."):
            sentence = sentence[:-2] + "."  # ピリオドの前のスペースを削除
        sentence = sentence[0].upper() + sentence[1:]  # 文の頭を大文字に
        outfile.write(f"{label} {sentence}\n")

# %%
input_file = "C:/Users/neoia/研究/mc_test_data.txt"
output_file = "C:/Users/neoia/研究/mc_test_data_new.txt"

with open(input_file, "r", encoding="utf-8") as infile, open(output_file, "w", encoding="utf-8") as outfile:
    for line in infile:
        line = line.strip()
        if not line:
            continue
        label, sentence = line[0], line[1:].strip()  # ラベルと文に分割
        if sentence.endswith(" ."):
            sentence = sentence[:-2] + "."  # ピリオドの前のスペースを削除
        sentence = sentence[0].upper() + sentence[1:]  # 文の頭を大文字に
        outfile.write(f"{label} {sentence}\n")
